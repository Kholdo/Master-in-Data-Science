# %%
import pandas as pd

# %%
pd.read_json('http://127.0.0.1:5000/return_num/100')
# Out:
#       arr_port    pax
# 0.0   LHR       88809
# 1.0   MCO       70930
# 10.0  ORD       53200
# 11.0  FCO       45120
# 12.0  IST       43850
# 13.0  DFW       42420
# 14.0  CUN       42000
# 15.0  MAD       41410
# 16.0  BCN       41200
# 17.0  LGA       40712
# 18.0  ATL       39780
# 19.0  EWR       36890
# 2.0   LAX       70530
# 20.0  BOS       35840
# 21.0  DEL       35680
# 22.0  SYD       33690
# 23.0  BOM       33440
# 24.0  MUC       33180
# 25.0  DEN       32630
# 26.0  MNL       32400
# 27.0  HKG       32020
# 28.0  FRA       31970
# 29.0  ORY       31800
# 3.0   LAS       69630
# 30.0  SEA       31530
# 31.0  FLL       31170
# 32.0  TXL       30590
# 33.0  AMS       30580
# 34.0  PHX       29730
# 35.0  DCA       29000
# ...        ...    ...
# 72.0  NRT       16570
# 73.0  LED       15960
# 74.0  YVR       15920
# 75.0  CPT       15840
# 76.0  MSY       15820
# 77.0  HAM       15640
# 78.0  PUJ       14960
# 79.0  AKL       14940
# 8.0   SFO       58000
# ...
